# %%
# import libraries
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split

# %%
# read in the data
df = pd.read_csv('titanic.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# cut down df to columns we want
df = df[['Survived', 'Pclass', 'Sex', 'Age', 'Fare']]
df.head()
# Out:
#    Survived  Pclass     Sex   Age     Fare
# 0         0       3    male  22.0   7.2500
# 1         1       1  female  38.0  71.2833
# 2         1       3  female  26.0   7.9250
# 3         1       1  female  35.0  53.1000
# 4         0       3    male  35.0   8.0500

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       714 non-null    float64
#  4   Fare      891 non-null    float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 34.9+ KB

# %%
# preprocess: drop nulls

df = df.dropna().reset_index(drop=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 714 entries, 0 to 713
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  714 non-null    int64
#  1   Pclass    714 non-null    int64
#  2   Sex       714 non-null    object
#  3   Age       714 non-null    float64
#  4   Fare      714 non-null    float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 28.0+ KB

# %%
# preprocess: onehot enconding of gender 
print(df.head())
encode = OneHotEncoder(drop='first')
list(encode.fit_transform(df[['Sex']]))
# Out:
#    Survived  Pclass     Sex   Age     Fare
# 0         0       3    male  22.0   7.2500
# 1         1       1  female  38.0  71.2833
# 2         1       3  female  26.0   7.9250
# 3         1       1  female  35.0  53.1000
# 4         0       3    male  35.0   8.0500
# [<Compressed Sparse Row sparse matrix of dtype 'float64'
#  	with 1 stored elements and shape (1, 1)>,
#  <Compressed Sparse Row sparse matrix of dtype 'float64'
#  	with 0 stored elements and shape (1, 1)>,
#  <Compressed Sparse Row sparse matrix of dtype 'float64'
#  	with 0 stored elements and shape (1, 1)>,
#  <Compressed Sparse Row sparse matrix of dtype 'float64'
#  	with 0 stored elements and shape (1, 1)>,
#  <Compressed Sparse Row sparse matrix of dtype 'float64'
#  	with 1 stored elements and shape (1, 1)>,
#  <Compressed Sparse Row sparse matrix of dtype 'float64'
#  	with 1 stored elements and shape (1, 1)>,
#  <Compressed Sparse Row sparse matrix of dtype 'float64'
# ...

# %%
# split data to make feature matrix and target vector
features = df[['Pclass', 'Sex', 'Age', 'Fare']]
target = df['Survived']

print(features.head())
print(target.head())
# Out:
#    Pclass     Sex   Age     Fare
# 0       3    male  22.0   7.2500
# 1       1  female  38.0  71.2833
# 2       3  female  26.0   7.9250
# 3       1  female  35.0  53.1000
# 4       3    male  35.0   8.0500
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
# train test split

# %%
# instantiate a model and call .fit on training data

# %%
# call .score() on test data to see how i did
