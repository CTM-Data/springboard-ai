# %%
import requests
import json

# %%
API_KEY = '2eqdE3nuyU8iWBx2kQrXSx3vYqVtcKhQJmR4u0fP'
url = f'https://api.eia.gov/v2/electricity/retail-sales/data/?api_key={API_KEY}&data[0]=price&frequency=monthly&facets[stateid][]=VA&start=2024-01&end=2024-03'

# %%
response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    print(json.dumps(data, indent=2))
else:
    print(f'Error: {response.status_code} - {response.text}')
# Out:
# {
#   "response": {
#     "total": "18",
#     "dateFormat": "YYYY-MM",
#     "frequency": "monthly",
#     "data": [
#       {
#         "period": "2024-02",
#         "stateid": "VA",
#         "stateDescription": "Virginia",
#         "sectorid": "ALL",
#         "sectorName": "all sectors",
#         "price": "10.77",
#         "price-units": "cents per kilowatt-hour"
#       },
#       {
#         "period": "2024-02",
#         "stateid": "VA",
#         "stateDescription": "Virginia",
#         "sectorid": "COM",
#         "sectorName": "commercial",
#         "price": "9.04",
#         "price-units": "cents per kilowatt-hour"
#       },
#       {
#         "period": "2024-02",
#         "stateid": "VA",
#         "stateDescription": "Virginia",
#         "sectorid": "IND",
#         "sectorName": "industrial",
#         "price": "8.55",
#         "price-units": "cents per kilowatt-hour"
#       },
#       {
#         "period": "2024-02",
#         "stateid": "VA",
# ...
